# %%
import cProfile
def main_run_code():
        path1 = input("输入论文原文的文件的绝对路径：")
        path2 = input("输入抄袭版论文的文件的绝对路径：")
        if not os.path.exists(path1):
            print("论文原文文件不存在！")
            exit()
        if not os.path.exists(path2):
            print("抄袭版论文文件不存在！")
            exit()
        save_path = "C:\\Users\\lenovo\\Desktop\\copy\\result.txt"
        content1 = get_file_contents(path1)
        content2 = get_file_contents(path2)
        text1 = filter_content(content1)
        text2 = filter_content(content2)
        similarity = calc_similarity(text1, text2)
        print("文章相似度：%.2f" % similarity)
        #将相似度结果写入指定文件
        f = open(save_path, 'w', encoding="utf-8")
        f.write("python"+" "+"main.py"+" "+path1+" "+path2+" "+"文章相似度： %.2f"%similarity)
        f.close()
cProfile.run('main_run_code()')
if __name__ == '__main__':
    main_run_code()
# Out:
# 输入论文原文的文件的绝对路径：C:\Users\lenovo\Desktop\copy\orig.txt
# 输入抄袭版论文的文件的绝对路径：C:\Users\lenovo\Desktop\copy\orig_0.8_add.txt
#          6632 function calls (6604 primitive calls) in 13.273 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   13.273   13.273 142669299.py:2(main_run_code)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:398(parent)
#         1    0.000    0.000   13.273   13.273 <string>:1(<module>)
#         8    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         8    0.000    0.000    0.000    0.000 __init__.py:299(loads)
#         4    0.000    0.000    0.000    0.000 _parser.py:1006(_find_hms_idx)
#         4    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         4    0.000    0.000    0.000    0.000 _parser.py:1061(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#         2    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#         6    0.000    0.000    0.000    0.000 _parser.py:1141(_to_decimal)
#         2    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#         2    0.000    0.000    0.000    0.000 _parser.py:1217(_build_naive)
#         2    0.000    0.000    0.000    0.000 _parser.py:1270(parse)
#         2    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#        26    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#         2    0.000    0.000    0.000    0.000 _parser.py:199(split)
#        28    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#        56    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#         8    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         2    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         2    0.000    0.000    0.000    0.000 _parser.py:233(__len__)
#        26    0.000    0.000    0.000    0.000 _parser.py:234(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         4    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         6    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         6    0.000    0.000    0.000    0.000 _parser.py:336(hms)
#         4    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         2    0.000    0.000    0.000    0.000 _parser.py:354(tzoffset)
#         2    0.000    0.000    0.000    0.000 _parser.py:360(convertyear)
#         2    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#         2    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         2    0.000    0.000    0.000    0.000 _parser.py:402(has_year)
#         6    0.000    0.000    0.000    0.000 _parser.py:428(append)
#         2    0.000    0.000    0.000    0.000 _parser.py:474(resolve_ymd)
#         2    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 _parser.py:572(parse)
#         2    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#         2    0.000    0.000    0.000    0.000 _parser.py:666(_parse)
#        26    0.000    0.000    0.000    0.000 _parser.py:77(get_token)
#         4    0.000    0.000    0.000    0.000 _parser.py:875(_parse_numeric_token)
#         8    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#      10/4    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 adapter.py:368(adapt)
#         8    0.000    0.000    0.000    0.000 decoder.py:332(decode)
#         8    0.000    0.000    0.000    0.000 decoder.py:343(raw_decode)
#         8    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#         8    0.000    0.000    0.000    0.000 encoder.py:182(encode)
#         8    0.000    0.000    0.000    0.000 encoder.py:204(iterencode)
#         2    0.000    0.000    0.000    0.000 error.py:109(__init__)
#         2    0.000    0.000    0.000    0.000 error.py:30(__init__)
#        16    0.000    0.000    0.000    0.000 hmac.py:111(update)
#         4    0.000    0.000    0.000    0.000 hmac.py:115(copy)
#         4    0.000    0.000    0.000    0.000 hmac.py:128(_current)
#         4    0.000    0.000    0.000    0.000 hmac.py:147(hexdigest)
#         8    0.000    0.000    0.000    0.000 iostream.py:208(schedule)
#         4    0.000    0.000    0.001    0.000 iostream.py:453(flush)
#         8    0.000    0.000    0.000    0.000 iostream.py:97(_event_pipe)
#         8    0.000    0.000    0.000    0.000 jsonapi.py:20(dumps)
#         8    0.000    0.000    0.000    0.000 jsonapi.py:28(loads)
#         6    0.000    0.000    0.000    0.000 jsonutil.py:31(_ensure_tzinfo)
#        12    0.000    0.000    0.001    0.000 jsonutil.py:44(parse_date)
#      16/4    0.000    0.000    0.001    0.000 jsonutil.py:59(extract_dates)
#       6/2    0.000    0.000    0.000    0.000 jsonutil.py:74(json_clean)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:84(date_default)
#         2    0.000    0.000   13.273    6.636 kernelbase.py:1064(raw_input)
#         2    0.011    0.006   13.273    6.636 kernelbase.py:1082(_input_request)
#         2    0.000    0.000    0.000    0.000 kernelbase.py:575(get_parent)
#       845   13.254    0.016   13.255    0.016 poll.py:108(select)
#         2    0.000    0.000    0.000    0.000 session.py:149(utcnow)
#         2    0.000    0.000    0.000    0.000 session.py:218(msg_header)
#         2    0.000    0.000    0.000    0.000 session.py:224(extract_header)
#         2    0.000    0.000    0.000    0.000 session.py:513(msg_id)
#         2    0.000    0.000    0.000    0.000 session.py:566(msg_header)
#         2    0.000    0.000    0.000    0.000 session.py:569(msg)
#         4    0.000    0.000    0.000    0.000 session.py:588(sign)
#         2    0.000    0.000    0.000    0.000 session.py:603(serialize)
#         2    0.000    0.000    0.000    0.000 session.py:662(send)
#         2    0.000    0.000    0.000    0.000 session.py:744(<listcomp>)
#         2    0.000    0.000    0.001    0.000 session.py:792(recv)
#         8    0.000    0.000    0.000    0.000 session.py:82(<lambda>)
#         2    0.000    0.000    0.000    0.000 session.py:826(feed_identities)
#         8    0.000    0.000    0.000    0.000 session.py:85(<lambda>)
#         2    0.000    0.000    0.000    0.000 session.py:863(_add_digest)
#         2    0.000    0.000    0.001    0.000 session.py:887(deserialize)
#         2    0.000    0.000    0.000    0.000 session.py:942(<listcomp>)
#        22    0.000    0.000    0.000    0.000 socket.py:480(send)
#         2    0.000    0.000    0.000    0.000 socket.py:549(send_multipart)
#         4    0.000    0.000    0.000    0.000 socket.py:599(recv_multipart)
#        12    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#        12    0.000    0.000    0.000    0.000 threading.py:1126(is_alive)
#         4    0.000    0.000    0.000    0.000 threading.py:228(__init__)
#         4    0.000    0.000    0.000    0.000 threading.py:256(__enter__)
#         4    0.000    0.000    0.000    0.000 threading.py:259(__exit__)
#         4    0.000    0.000    0.000    0.000 threading.py:265(_release_save)
#         4    0.000    0.000    0.000    0.000 threading.py:268(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 threading.py:271(_is_owned)
#         4    0.000    0.000    0.000    0.000 threading.py:280(wait)
#         4    0.000    0.000    0.000    0.000 threading.py:521(__init__)
#        12    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         4    0.000    0.000    0.000    0.000 threading.py:556(wait)
#      1762    0.002    0.000    0.002    0.000 traitlets.py:535(get)
#      1762    0.002    0.000    0.005    0.000 traitlets.py:566(__get__)
#         2    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         4    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFFC3B1BC60}
#         8    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#      10/4    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _hashlib.compare_digest}
#         4    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   13.273   13.273 {built-in method builtins.exec}
#        38    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        28    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        12    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       885    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        12    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#         6    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#        28    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        64    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         8    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        14    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        50    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 22>()
#      20         f.write("python"+" "+"main.py"+" "+path1+" "+path2+" "+"文章相似度： %.2f"%similarity)
#      21         f.close()
# ---> 22 cProfile.run('main_run_code()')
#      23 if __name__ == '__main__':
#      24     main_run_code()
#
# File ~\anaconda3\lib\cProfile.py:16, in run(statement, filename, sort)
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File ~\anaconda3\lib\profile.py:53, in _Utils.run(self, statement, filename, sort)
#      51 prof = self.profiler()
#      52 try:
# ---> 53     prof.run(statement)
#      54 except SystemExit:
#      55     pass
#
# File ~\anaconda3\lib\cProfile.py:95, in Profile.run(self, cmd)
#      93 import __main__
#      94 dict = __main__.__dict__
# ---> 95 return self.runctx(cmd, dict, dict)
#
# File ~\anaconda3\lib\cProfile.py:100, in Profile.runctx(self, cmd, globals, locals)
#      98 self.enable()
#      99 try:
# --> 100     exec(cmd, globals, locals)
#     101 finally:
#     102     self.disable()
#
# File <string>:1, in <module>
#
# Input In [1], in main_run_code()
#       3 path1 = input("输入论文原文的文件的绝对路径：")
#       4 path2 = input("输入抄袭版论文的文件的绝对路径：")
# ----> 5 if not os.path.exists(path1):
#       6     print("论文原文文件不存在！")
#       7     exit()
#
# NameError: name 'os' is not defined
