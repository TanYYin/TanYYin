# %%
import unittest
from plagiarism import short_analyse, ans

class PaperSimilarityTestCase(unittest.TestCase):
    def setUp(self):
        self.original_file = 'orig.txt'
        self.copied_file = 'orig_0.8_add.txt'
    
    def test_short_analyse(self):
        # Call the short_analyse function
        short_analyse(self.original_file, self.copied_file)
        
        # Additional assertions if needed
        # ...
    
    def test_ans(self):
        # Call the ans function
        similarity = ans(self.original_file, self.copied_file)
        
        # Perform assertions to verify the expected similarity value
        expected_similarity = 80  # Assuming the expected similarity is 80%
        self.assertEqual(similarity, expected_similarity, 
            "The calculated similarity doesn't match the expected value.")

# Manually create a TestSuite and add the test cases
suite = unittest.TestSuite()
suite.addTest(PaperSimilarityTestCase('test_short_analyse'))
suite.addTest(PaperSimilarityTestCase('test_ans'))

# Create a test runner
runner = unittest.TextTestRunner()
# Run the tests
result = runner.run(suite)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 0.438 seconds.
# Prefix dict has been built successfully.
# 余弦相似度为：0.590000
# ['自私', '仿掖', '第一章', '啊', '棵', '进祖', '爹降', '夕阳', '感奉', '赡', '蒸', '摊着', '姑', '往前走', '荒暗', '巩', '途径', '一孟百', '拥有者', '一句', '没钱趣', '萎丧', '孩子', '瘦', '止', '我点', '猫眼', '玫', '鼓', '灶', '占满', '些小', '拄', '所淆', '稀奇', '犹如', '金', '连', '越远', '芹干圈', '突出', '说道', '晰', '人才', '溪口', '水面', '恢', '低', '赢', '袖管', '忽', '车轮', '越大', '衣衫', '青草', '包', '存心', '难', '目光', '录沈先', '赶紧', '苍蝇', '牌南亮', '藏到', '回', '根本', '这个', '不好', '撩', '牲畜', '奋', '心放', '接连', '夜路', '那位', '二辩', '多少', '唱', '两龙争', '大小', '废话', '代替', '起饰', '晾', '盘子', '光芒', '干', '虚', '女存', '生活', '耕', '般地', '废', '黑颜筐', '看到', '汗', '女人家', '摸牌', '控诉', '季节', '棍', '正是', '别冰', '波浪', '来', '仙', '烦娘', '过程', '镇', '想', '捂着', '佣福贵', '一个', '获得', '窜', '珠', '懦接', '树叶', '回绪答', '履', '糟蹋', '潜', '照看', '甚', '煽', '臀', '姿喊', '屁股', '纹', '只有', '焊飞', '逃之夭夭', '幌', '喻在', '中央', '多亩', '故事会', '敲打', '为什么', '昌', '吠', '脱下', '容易', '闪闪', '投', '后', '脱帽', '藩', '恶', '我俩', '狰', '私塾', '天天', '多', '坯', '皋', '贬人黝', '阿里', '葬', '鼻青眼肿', '我会', '艾', '顶撞', '树干', '几下', '巴', '地说', '他准', '的话', '物', '小住', '喳龙', '念', '抑', '不烟', '告辞', '锄头', '猫', '碘', '会', '苍子', '绒像', '永远', '丫头', '悄歉', '伶', '痹', '尽', '喜爱', '遇上', '力气', '报晓', '门板', '视', '枕着', '项圈', '钡', '犹羽', '田边', '札', '变', '娥', '扇门', '愿意', '放在', '有个', '皱', '骑米', '特', '很多', '承受能力', '羔上', '人彰', '进一步', '虚幻', '当溜初', '说不清', '一紧', '比渺', '赌输', '照射', '漏说', '心里打鼓', '泵', '活着', '杨', '开导', '烟囱', '身袍', '蜀', '喘奇', '钻', '垂暮', '已经', '古板', '刁', '躺', '不得不', '榜', '型', '多么', '野输', '随着', '怨', '咨', '同情', '衔', '放', '任何事物', '黑', '快刀', '人', '沉不住气', '岁', '吆喝', '输过', '说赞', '家', '老输', '阁', '夏天', '俊', '借门', '恃', '必须', '蓝布', '每次', '去', '度', '想象', '本身', '看家', '鸟爪', '那堡', '绣', '连存', '背廓', '麻雀', '出于', '锌', '深深', '词帝', '边', '检地嘎流', '夜里', '颜', '毋', '翠', '中间', '娘肚', '细气', '掉', '纪大', '写', '透亮', '沉湎', '薛', '羞怯', '显人', '咳嗽', '白绸', '频龙府', '涨来', '他贤气', '条箱', '一眼', '地堤', '秒', '助', '一服', '戌', '平息', '哗', '船上', '赌云博', '这贯', '农忙', '细祟声', '爹趣', '名叫', '却是', '鄂', '想狈', '挂', '兢头', '几纷次', '非我莫属', '鸡', '反', '盈奖', '翻动', '很大', '可味', '豌单', '拼', '垄量', '什痔', '毛巾', '猪肉', '手饰', '嫁给', '气得', '爹敬', '进进出出', '无恙', '律', '一身', '鳃', '按', '邢', '贵', '瘪', '摧实', '那', '屏', '炎热', '牛笆', '事物', '有惠', '除', '背包', '楚裆', '敞开', '蜂拥而来', '耙', '看誓', '一渤声', '地夯', '鲤往', '纤', '曙', '见', '笑容', '回瞪去', '了', '重粥', '究竟', '历史', '姑树下', '算计', '败落', '干什么', '五张', '低下头去', '前', '推了', '昂', '行力', '殷勤', '放差', '诞是', '实实在在', '枉', '脸', '井旁', '箍', '赌注', '推烂', '发现自己', '几声', '秩事', '咧着', '诧荫里', '眨', '不管', '暗地里', '绚你疆', '吗', '里面', '这测', '婴滑', '难看', '递过', '沮板', '扶住', '来狈', '下面', '看得', '赢桐', '痉气', '纯煊', '恢光', '兴趣', '剪', '米', '一碗', '手时', '悄声', '编着', '哪些', '揭', '赌剖博', '狄', '近', '问吼', '紧张', '空', '往里面', '我朋爹', '乡间', '偷访', '镊', '酸曲', '村口', '说不清楚', '绸衫', '抬脚', '急', '吼道', '就', '馆后', '看', '证着', '遇到', '嘟嘟', '唉声叹气', '却', '肋', '输', '断子绝孙', '这形', '龙二赌', '胸口', '紊面澈', '犁', '每吉', '耐', '不可', '同时', '收起', '兄弟', '大矽', '说过', '钠', '令', '得意', '飞', '不动', '依然', '眼睛', '等到', '拖出去', '几句', '尖', '卧', '看看', '一客', '实实在', '经过', '殃', '另泪', '令人感动', '穿', '二流', '不栗', '死去', '喉', '后面', '照亮', '他们', '身心愉快', '脊', '算了吧', '爪子', '重', '其撒间', '身旁', '擒', '一棵', '就算', '书时', '输沈先', '刚才', '二流子', '麻将', '状们', '前往', '对', '抓丈', '蓬', '摧', '株亩', '钉辕', '一辈子', '铲', '像', '眼泪汪汪', '头戴', '力', '方', '土地', '叫', '手上', '俩', '动弹不得', '有生以来', '十天', '摆弄', '爹问', '他态', '衙', '枕', '悼地', '女盆人', '嚣', '活察着', '引子', '乱', '这篇', '上师', '岳父', '老亭', '明确', '田地', '朽木', '儿媳', '怯滞', '锰', '先生', '闭看', '聊', '度过', '醛', '拍打着', '毫无顾忌', '常常', '我束', '一生', '眉头', '而出', '猩', '氏', '套', '老板', '方便', '过大瓣', '守', '嗓音', '慢送', '轿程', '怎么', '路', '拉屎', '径', '吃喝', '推过来', '各不相同', '扬长而去', '麻将牌', '庐态', '那里', '毒有', '长睛', '务', '大腿', '人们', '这位', '人球文', '款', '后来', '自从', '艰', '上来', '说不出来', '亮', '颓人', '风声', '们', '那么', '早晨', '坐近', '逛街', '人群', '似爷', '鸽', '披散', '打佬动', '管不住', '每', '削弱', '有册', '最后', '姑娘', '蘑', '吻', '经旗历', '晌排', '总该有', '盯', '裤', '我伍', '我要', '胜负', '扛', '琢', '时候', '丫擦', '步', '出生', '座', '邀一玖', '撩起', '哎', '闭', '梢', '饱嗝', '蕊', '越输', '花甲', '粗哑', '不输龙', '一站', '一声', '帮', '段压', '让', '发过现', '太多', '不住', '德', '讯', '人家', '织', '穆屎', '一只', '吵', '一癌', '爷', '匣', '往回', '肩膀', '一藩', '丽', '喝醉', '收集', '屋里', '时香常', '妓满', '镶满', '跪', '谷', '馏地', '拷身', '墨', ...
# .F
# ======================================================================
# FAIL: test_ans (plagiarism.PaperSimilarityTestCase)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Desktop\copy\plagiarism.py", line 184, in test_ans
#     self.assertEqual(similarity, expected_similarity,
# AssertionError: 81.82 != 80 : The calculated similarity doesn't match the expected value.
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.668s
#
# FAILED (failures=1)
# 两篇文章的相似度为0.9916826613553886
# ['自私', '仿掖', '第一章', '啊', '棵', '进祖', '爹降', '夕阳', '感奉', '赡', '蒸', '摊着', '姑', '往前走', '荒暗', '巩', '途径', '一孟百', '拥有者', '一句', '没钱趣', '萎丧', '孩子', '瘦', '止', '我点', '猫眼', '玫', '鼓', '灶', '占满', '些小', '拄', '所淆', '稀奇', '犹如', '金', '连', '越远', '芹干圈', '突出', '说道', '晰', '人才', '溪口', '水面', '恢', '低', '赢', '袖管', '忽', '车轮', '越大', '衣衫', '青草', '包', '存心', '难', '目光', '录沈先', '赶紧', '苍蝇', '牌南亮', '藏到', '回', '根本', '这个', '不好', '撩', '牲畜', '奋', '心放', '接连', '夜路', '那位', '二辩', '多少', '唱', '两龙争', '大小', '废话', '代替', '起饰', '晾', '盘子', '光芒', '干', '虚', '女存', '生活', '耕', '般地', '废', '黑颜筐', '看到', '汗', '女人家', '摸牌', '控诉', '季节', '棍', '正是', '别冰', '波浪', '来', '仙', '烦娘', '过程', '镇', '想', '捂着', '佣福贵', '一个', '获得', '窜', '珠', '懦接', '树叶', '回绪答', '履', '糟蹋', '潜', '照看', '甚', '煽', '臀', '姿喊', '屁股', '纹', '只有', '焊飞', '逃之夭夭', '幌', '喻在', '中央', '多亩', '故事会', '敲打', '为什么', '昌', '吠', '脱下', '容易', '闪闪', '投', '后', '脱帽', '藩', '恶', '我俩', '狰', '私塾', '天天', '多', '坯', '皋', '贬人黝', '阿里', '葬', '鼻青眼肿', '我会', '艾', '顶撞', '树干', '几下', '巴', '地说', '他准', '的话', '物', '小住', '喳龙', '念', '抑', '不烟', '告辞', '锄头', '猫', '碘', '会', '苍子', '绒像', '永远', '丫头', '悄歉', '伶', '痹', '尽', '喜爱', '遇上', '力气', '报晓', '门板', '视', '枕着', '项圈', '钡', '犹羽', '田边', '札', '变', '娥', '扇门', '愿意', '放在', '有个', '皱', '骑米', '特', '很多', '承受能力', '羔上', '人彰', '进一步', '虚幻', '当溜初', '说不清', '一紧', '比渺', '赌输', '照射', '漏说', '心里打鼓', '泵', '活着', '杨', '开导', '烟囱', '身袍', '蜀', '喘奇', '钻', '垂暮', '已经', '古板', '刁', '躺', '不得不', '榜', '型', '多么', '野输', '随着', '怨', '咨', '同情', '衔', '放', '任何事物', '黑', '快刀', '人', '沉不住气', '岁', '吆喝', '输过', '说赞', '家', '老输', '阁', '夏天', '俊', '借门', '恃', '必须', '蓝布', '每次', '去', '度', '想象', '本身', '看家', '鸟爪', '那堡', '绣', '连存', '背廓', '麻雀', '出于', '锌', '深深', '词帝', '边', '检地嘎流', '夜里', '颜', '毋', '翠', '中间', '娘肚', '细气', '掉', '纪大', '写', '透亮', '沉湎', '薛', '羞怯', '显人', '咳嗽', '白绸', '频龙府', '涨来', '他贤气', '条箱', '一眼', '地堤', '秒', '助', '一服', '戌', '平息', '哗', '船上', '赌云博', '这贯', '农忙', '细祟声', '爹趣', '名叫', '却是', '鄂', '想狈', '挂', '兢头', '几纷次', '非我莫属', '鸡', '反', '盈奖', '翻动', '很大', '可味', '豌单', '拼', '垄量', '什痔', '毛巾', '猪肉', '手饰', '嫁给', '气得', '爹敬', '进进出出', '无恙', '律', '一身', '鳃', '按', '邢', '贵', '瘪', '摧实', '那', '屏', '炎热', '牛笆', '事物', '有惠', '除', '背包', '楚裆', '敞开', '蜂拥而来', '耙', '看誓', '一渤声', '地夯', '鲤往', '纤', '曙', '见', '笑容', '回瞪去', '了', '重粥', '究竟', '历史', '姑树下', '算计', '败落', '干什么', '五张', '低下头去', '前', '推了', '昂', '行力', '殷勤', '放差', '诞是', '实实在在', '枉', '脸', '井旁', '箍', '赌注', '推烂', '发现自己', '几声', '秩事', '咧着', '诧荫里', '眨', '不管', '暗地里', '绚你疆', '吗', '里面', '这测', '婴滑', '难看', '递过', '沮板', '扶住', '来狈', '下面', '看得', '赢桐', '痉气', '纯煊', '恢光', '兴趣', '剪', '米', '一碗', '手时', '悄声', '编着', '哪些', '揭', '赌剖博', '狄', '近', '问吼', '紧张', '空', '往里面', '我朋爹', '乡间', '偷访', '镊', '酸曲', '村口', '说不清楚', '绸衫', '抬脚', '急', '吼道', '就', '馆后', '看', '证着', '遇到', '嘟嘟', '唉声叹气', '却', '肋', '输', '断子绝孙', '这形', '龙二赌', '胸口', '紊面澈', '犁', '每吉', '耐', '不可', '同时', '收起', '兄弟', '大矽', '说过', '钠', '令', '得意', '飞', '不动', '依然', '眼睛', '等到', '拖出去', '几句', '尖', '卧', '看看', '一客', '实实在', '经过', '殃', '另泪', '令人感动', '穿', '二流', '不栗', '死去', '喉', '后面', '照亮', '他们', '身心愉快', '脊', '算了吧', '爪子', '重', '其撒间', '身旁', '擒', '一棵', '就算', '书时', '输沈先', '刚才', '二流子', '麻将', '状们', '前往', '对', '抓丈', '蓬', '摧', '株亩', '钉辕', '一辈子', '铲', '像', '眼泪汪汪', '头戴', '力', '方', '土地', '叫', '手上', '俩', '动弹不得', '有生以来', '十天', '摆弄', '爹问', '他态', '衙', '枕', '悼地', '女盆人', '嚣', '活察着', '引子', '乱', '这篇', '上师', '岳父', '老亭', '明确', '田地', '朽木', '儿媳', '怯滞', '锰', '先生', '闭看', '聊', '度过', '醛', '拍打着', '毫无顾忌', '常常', '我束', '一生', '眉头', '而出', '猩', '氏', '套', '老板', '方便', '过大瓣', '守', '嗓音', '慢送', '轿程', '怎么', '路', '拉屎', '径', '吃喝', '推过来', '各不相同', '扬长而去', '麻将牌', '庐态', '那里', '毒有', '长睛', '务', '大腿', '人们', '这位', '人球文', '款', '后来', '自从', '艰', '上来', '说不出来', '亮', '颓人', '风声', '们', '那么', '早晨', '坐近', '逛街', '人群', '似爷', '鸽', '披散', '打佬动', '管不住', '每', '削弱', '有册', '最后', '姑娘', '蘑', '吻', '经旗历', '晌排', '总该有', '盯', '裤', '我伍', '我要', '胜负', '扛', '琢', '时候', '丫擦', '步', '出生', '座', '邀一玖', '撩起', '哎', '闭', '梢', '饱嗝', '蕊', '越输', '花甲', '粗哑', '不输龙', '一站', '一声', '帮', '段压', '让', '发过现', '太多', '不住', '德', '讯', '人家', '织', '穆屎', '一只', '吵', '一癌', '爷', '匣', '往回', '肩膀', '一藩', '丽', '喝醉', '收集', '屋里', '时香常', '妓满', '镶满', '跪', '谷', '馏地', '拷身', '墨', ...
# .F
# ======================================================================
# FAIL: test_ans (__main__.PaperSimilarityTestCase)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_16120\3015844496.py", line 22, in test_ans
#     self.assertEqual(similarity, expected_similarity,
# AssertionError: 81.82 != 80 : The calculated similarity doesn't match the expected value.
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.689s
#
# FAILED (failures=1)
# 两篇文章的相似度为0.9916826613553886

# %%
import cProfile
import unittest
import os
from plagiarism import filter_content, calc_similarity

class TestTextSimilarity(unittest.TestCase):

    def test_filter_content(self):
        text = "这是一个测试文本，包含一些特殊符号和停用词。"
        result = filter_content(text)
        expected_result = ["测试", "文本", "包含", "特殊", "符号", "停用词"]
        self.assertEqual(result, expected_result)
    
    def test_calc_similarity(self):
        text1 = "这是一篇原始论文。"
        text2 = "这是一篇相似的抄袭论文。"
        similarity = calc_similarity(text1, text2)
        self.assertAlmostEqual(similarity, 0.8, delta=0.05)  # 预测相似度为0.8左右，允许误差为0.05
if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: C:\Users\lenovo\AppData\Roaming\jupyter\runtime\kernel-77a8650e-b92b-4d7a-80ca-083d95710e69 (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\lenovo\AppData\Roaming\jupyter\runtime\kernel-77a8650e-b92b-4d7a-80ca-083d95710e69'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# C:\Users\lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
